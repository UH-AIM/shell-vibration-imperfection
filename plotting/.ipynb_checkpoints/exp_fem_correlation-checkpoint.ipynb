# %%
import cv2
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

colors=["#007894","#A7117A"] #petrol,purple

MM_TO_PT = 72 / 25.4
font_size_mm = 2.5
font_size_pt = font_size_mm * MM_TO_PT  # ≈ 8.5 pt
mpl.rcParams.update({
    "font.family": "sans-serif",
    "font.sans-serif": ["Arial"],
    "font.size": font_size_pt,
    "axes.labelsize": font_size_pt,
    "axes.titlesize": font_size_pt,
    "xtick.labelsize": font_size_pt,
    "ytick.labelsize": font_size_pt,
    "legend.fontsize": font_size_pt,
})

# %% [markdown]
# #### 6 bumps

# %%
n_bump = '06'

exp_theta = np.loadtxt('../data/exp_fem_corr_'+n_bump+'_exp_theta.csv', delimiter=',', dtype=float)
exp_prof_mean = np.loadtxt('../data/exp_fem_corr_'+n_bump+'_exp_prof_mean.csv', delimiter=',', dtype=float)
exp_prof_std = np.loadtxt('../data/exp_fem_corr_'+n_bump+'_exp_prof_std.csv', delimiter=',', dtype=float)
sim_theta = np.loadtxt('../data/exp_fem_corr_'+n_bump+'_sim_theta.csv', delimiter=',', dtype=float)
sim_prof = np.loadtxt('../data/exp_fem_corr_'+n_bump+'_sim_prof.csv', delimiter=',', dtype=float)

# Create figure with two subplots
fig, ax1 = plt.subplots(figsize=(30./25.4,30/25.4))

# mean curve
ax1.plot(exp_theta, exp_prof_mean, '--', label="Exp thickness", color=colors[0],linewidth=0.75)
ax1.plot(sim_theta, sim_prof, label="Sim Mode", color=colors[1],linewidth=0.75, alpha=0.75)

# shaded ± std region
ax1.fill_between(
    exp_theta,
    exp_prof_mean - exp_prof_std,
    exp_prof_mean + exp_prof_std,
    alpha=0.25,
    color=colors[0], 
)

ax1.set_xlim(0, 2)
ax1.set_ylim(0.45,1.05)

ax1.legend(
    frameon=False,
    handlelength=1.2,
    handletextpad=0.4,
    borderpad=0,
    labelspacing=0.2
)

ax1.tick_params(left=False, labelleft=False)
ax1.set_xlabel(r"Angle $\theta$ ($\pi$)", labelpad=1)
ax1.set_ylabel(r"Intensity, I($\theta$)", labelpad=1)
ax1.tick_params(axis='both', pad=1)

fig.tight_layout(pad=0.5)
plt.show()

# %% [markdown]
# #### 8 bumps

# %%
n_bump = '08'

exp_theta = np.loadtxt('../data/exp_fem_corr_'+n_bump+'_exp_theta.csv', delimiter=',', dtype=float)
exp_prof_mean = np.loadtxt('../data/exp_fem_corr_'+n_bump+'_exp_prof_mean.csv', delimiter=',', dtype=float)
exp_prof_std = np.loadtxt('../data/exp_fem_corr_'+n_bump+'_exp_prof_std.csv', delimiter=',', dtype=float)
sim_theta = np.loadtxt('../data/exp_fem_corr_'+n_bump+'_sim_theta.csv', delimiter=',', dtype=float)
sim_prof = np.loadtxt('../data/exp_fem_corr_'+n_bump+'_sim_prof.csv', delimiter=',', dtype=float)

# Create figure with two subplots
fig, ax1 = plt.subplots(figsize=(30./25.4,30/25.4))

# mean curve
ax1.plot(exp_theta, exp_prof_mean, '--', label="Exp thickness", color=colors[0],linewidth=0.75)
ax1.plot(sim_theta, sim_prof, label="Sim Mode", color=colors[1],linewidth=0.75, alpha=0.75)

# shaded ± std region
ax1.fill_between(
    exp_theta,
    exp_prof_mean - exp_prof_std,
    exp_prof_mean + exp_prof_std,
    alpha=0.25,
    color=colors[0], 
)

ax1.set_xlim(0, 2)
ax1.set_ylim(0.45,1.05)

ax1.legend(
    frameon=False,
    handlelength=1.2,
    handletextpad=0.4,
    borderpad=-.2,
    labelspacing=0.2
)

ax1.tick_params(left=False, labelleft=False)
ax1.set_xlabel(r"Angle $\theta$ ($\pi$)", labelpad=1)
ax1.tick_params(axis='both', pad=1)

fig.tight_layout(pad=0.5)
plt.show()

# %% [markdown]
# ### 10 bumps

# %%
n_bump = '10'

exp_theta = np.loadtxt('../data/exp_fem_corr_'+n_bump+'_exp_theta.csv', delimiter=',', dtype=float)
exp_prof_mean = np.loadtxt('../data/exp_fem_corr_'+n_bump+'_exp_prof_mean.csv', delimiter=',', dtype=float)
exp_prof_std = np.loadtxt('../data/exp_fem_corr_'+n_bump+'_exp_prof_std.csv', delimiter=',', dtype=float)
sim_theta = np.loadtxt('../data/exp_fem_corr_'+n_bump+'_sim_theta.csv', delimiter=',', dtype=float)
sim_prof = np.loadtxt('../data/exp_fem_corr_'+n_bump+'_sim_prof.csv', delimiter=',', dtype=float)

# Create figure with two subplots
fig, ax1 = plt.subplots(figsize=(30./25.4,30/25.4))

# mean curve
ax1.plot(exp_theta, exp_prof_mean, '--', label="Exp thickness", color=colors[0],linewidth=0.75)
ax1.plot(sim_theta, sim_prof, label="Sim Mode", color=colors[1],linewidth=0.75, alpha=0.75)

# shaded ± std region
ax1.fill_between(
    exp_theta,
    exp_prof_mean - exp_prof_std,
    exp_prof_mean + exp_prof_std,
    alpha=0.25,
    color=colors[0], 
)

ax1.set_xlim(0, 2)
ax1.set_ylim([0.45,1.05])

ax1.legend(
    frameon=False,
    handlelength=1.2,
    handletextpad=0.4,
    borderpad=-.2,
    labelspacing=0.2
)

ax1.tick_params(left=False, labelleft=False)
ax1.set_xlabel(r"Angle $\theta$ ($\pi$)", labelpad=1)
ax1.tick_params(axis='both', pad=1)


fig.tight_layout(pad=0.5)
plt.show()
